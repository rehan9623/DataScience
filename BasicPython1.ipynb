# %%
#Basics of pyhton

# %%
a = 1

# %%
b = 99

# %%
a + b
# Out:
# 100

# %%
name = "Rehan"

# %%
print(name)
# Out:
# Rehan

# %%
x = "3673848"

# %%
y = "63637855"

# %%
int(x)+int(y)
# Out:
# 67311703
