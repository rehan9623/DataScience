# %%
name = "Harry"

# %%
name
# Out:
# 'Harry'

# %%
name.endswith("y")
# Out:
# True

# %%
name.capitalize
# Out:
# <function str.capitalize()>

# %%
name.upper()
# Out:
# 'HARRY'

# %%
name.count("r")
# Out:
# 2

# %%
name[0:5]
# Out:
# 'Harry'

# %%
name[0:3]
# Out:
# 'Har'

# %%
name[-2:5]
# Out:
# 'ry'
